# %%
# !pip install -r ../requirements.txt

# %% [markdown]
# Import Dependancies

# %%
import numpy as np
import pandas as pd
import os #if im not know about my current library
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/processed/ChurnModeling_Binning_Applied.csv')
df.head()
# Out:
#   Geography  Gender    Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0    France  Female  42.00       2       0.00              1          1
# 1     Spain  Female  41.00       1   83807.86              1          0
# 2    France  Female  42.00       8  159660.80              3          1
# 3    France  Female  38.91       1       0.00              2          0
# 4     Spain  Female  43.00       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited CreditScoreBins
# 0               1        101348.88       1            fair
# 1               1        112542.58       0            fair
# 2               0        113931.57       1            poor
# 3               0         93826.63       0            Good
# 4               1         79084.10       0             NaN

# %% [markdown]
# Nominal => One-Hot encoding
# Ordinal => Label Encoding

# %% [markdown]
# consider Gender<Male,Female>(Assuming gender is nominal)
# from one-hot encoding it will create two columns that are Gender_Male,Gendder_Female
#
#
# if Gender is Ordinal
# Male => 1
# female => 0

# %%
 Gender --> Nominal
 Geography --> Nominal
 CreditScoreBins --> Ordinal

# %% [markdown]
# Encode Ordinal Variables

# %%
credit_score_dummies = pd.get_dummies(df['CreditScoreBins'],prefix="CreditScore")
credit_score_dummies
# Out:
#       CreditScore_Good  CreditScore_Very Good  CreditScore_excellent  \
# 0                False                  False                  False
# 1                False                  False                  False
# 2                False                  False                  False
# 3                 True                  False                  False
# 4                False                  False                  False
# ...                ...                    ...                    ...
# 9995             False                   True                  False
# 9996             False                  False                  False
# 9997              True                  False                  False
# 9998             False                   True                  False
# 9999             False                   True                  False
#
#       CreditScore_fair  CreditScore_poor
# 0                 True             False
# 1                 True             False
# ...

# %%
df_encoded = pd.concat([df,credit_score_dummies],axis=1)
del df_encoded['CreditScoreBins']
df_encoded
# Out:
#      Geography  Gender    Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0       France  Female  42.00       2       0.00              1          1
# 1        Spain  Female  41.00       1   83807.86              1          0
# 2       France  Female  42.00       8  159660.80              3          1
# 3       France  Female  38.91       1       0.00              2          0
# 4        Spain  Female  43.00       2  125510.82              1          1
# ...        ...     ...    ...     ...        ...            ...        ...
# 9995    France    Male  39.00       5       0.00              2          1
# 9996    France    Male  35.00      10   57369.61              1          1
# 9997    France  Female  36.00       7       0.00              1          0
# 9998   Germany    Male  42.00       3   75075.31              2          1
# 9999    France  Female  28.00       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  CreditScore_Good  \
# ...

# %% [markdown]
# Encode Nomminal Variables
