# %%
# !pip install -r ../requirements.txt

# %% [markdown]
# Import Dependancies

# %%
import numpy as np
import pandas as pd
import os #if im not know about my current library
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/processed/ChurnModeling_Binning_Applied.csv')
df.head()
# Out:
#   Geography  Gender    Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0    France  Female  42.00       2       0.00              1          1
# 1     Spain  Female  41.00       1   83807.86              1          0
# 2    France  Female  42.00       8  159660.80              3          1
# 3    France  Female  38.91       1       0.00              2          0
# 4     Spain  Female  43.00       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited CreditScoreBins
# 0               1        101348.88       1            fair
# 1               1        112542.58       0            fair
# 2               0        113931.57       1            poor
# 3               0         93826.63       0            Good
# 4               1         79084.10       0             NaN

# %% [markdown]
# Nominal => One-Hot encoding
# Ordinal => Label Encoding

# %% [markdown]
# consider Gender<Male,Female>(Assuming gender is nominal)
# from one-hot encoding it will create two columns that are Gender_Male,Gendder_Female
#
#
# if Gender is Ordinal
# Male => 1
# female => 0

# %%
 Gender --> Nominal
 Geography --> Nominal
 CreditScoreBins --> Ordinal

# %% [markdown]
# Encode Nomminal Variables

# %%
nominal_variables = ['Geography','Gender']
#can don easily using sciking-learning label encoder

Geography_dummies = pd.get_dummies(df['Geography'],prefix='Geography')
Geography_dummies
df_encoded = pd.concat([df,Geography_dummies],axis=1)
del df_encoded['Geography']
df_encoded
# Out:
#       Gender    Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0     Female  42.00       2       0.00              1          1
# 1     Female  41.00       1   83807.86              1          0
# 2     Female  42.00       8  159660.80              3          1
# 3     Female  38.91       1       0.00              2          0
# 4     Female  43.00       2  125510.82              1          1
# ...      ...    ...     ...        ...            ...        ...
# 9995    Male  39.00       5       0.00              2          1
# 9996    Male  35.00      10   57369.61              1          1
# 9997  Female  36.00       7       0.00              1          0
# 9998    Male  42.00       3   75075.31              2          1
# 9999  Female  28.00       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited CreditScoreBins  \
# 0                  1        101348.88       1            fair
# ...

# %%
Gender_dummies = pd.get_dummies(df_encoded['Gender'],prefix='Gender')
df_encoded = pd.concat([df_encoded,Gender_dummies],axis=1)  
del df_encoded['Gender']
df_encoded
# Out:
#         Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0     42.00       2       0.00              1          1               1
# 1     41.00       1   83807.86              1          0               1
# 2     42.00       8  159660.80              3          1               0
# 3     38.91       1       0.00              2          0               0
# 4     43.00       2  125510.82              1          1               1
# ...     ...     ...        ...            ...        ...             ...
# 9995  39.00       5       0.00              2          1               0
# 9996  35.00      10   57369.61              1          1               1
# 9997  36.00       7       0.00              1          0               1
# 9998  42.00       3   75075.31              2          1               0
# 9999  28.00       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited CreditScoreBins  Geography_France  \
# ...

# %% [markdown]
# Encode Ordinal Variables

# %%
crei_score_unique = df_encoded['CreditScoreBins'].unique()
crei_score_unique
# Out:
# array(['fair', 'poor', 'Good', nan, 'excellent', 'Very Good'],
#       dtype=object)

# %%
encode_dict_creditscore = {

                            'poor':0,
                            'fair':1,
                            'Good':2,
                            ''	
                             
                        }
