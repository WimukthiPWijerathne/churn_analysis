# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.3 MB 381.6 kB/s eta 0:00:29
#    - -------------------------------------- 0.5/11.3 MB 381.6 kB/s eta 0:00:29
#    -- ------------------------------------- 0.8/11.3 MB 472.8 kB/s eta 0:00:23
#    --- ------------------------------------ 1.0/11.3 MB 553.0 kB/s eta 0:00:19
#    ---- ----------------------------------- 1.3/11.3 MB 658.2 kB/s eta 0:00:16
#    ---- ----------------------------------- 1.3/11.3 MB 658.2 kB/s eta 0:00:16
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %% [markdown]
# !pip install -r ../requirements.txt

# %%
# !pip install -r ../requirements.txt
# Out:
# ...
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# ...
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.9 MB 1.2 MB/s eta 0:00:07
#    --- ------------------------------------ 0.8/8.9 MB 1.2 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.0/8.9 MB 1.3 MB/s eta 0:00:07
#    ------- -------------------------------- 1.6/8.9 MB 1.4 MB/s eta 0:00:06
#    -------- ------------------------------- 1.8/8.9 MB 1.4 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.4/8.9 MB 1.6 MB/s eta 0:00:05
#    ------------ --------------------------- 2.9/8.9 MB 1.7 MB/s eta 0:00:04
#    --------------- ------------------------ 3.4/8.9 MB 1.8 MB/s eta 0:00:04
# ...

# %% [markdown]
# ### 1.Import dependencies

# %%
import numpy as np
import openai,groq
import pandas as pd
import os #if im not know about my current library

# %% [markdown]
# ### 2.Basic Information

# %%
os.getcwd()
# Out:
# 'e:\\zuucrew\\week01'

# %%
df = pd.read_csv('data/raw/ChurnModelling.csv')
df.head(10)
# Out:
#    RowNumber  CustomerId Firstname  Lastname  CreditScore Geography  Gender  \
# 0          1    15634602     Grace  Williams          619    France  Female
# 1          2    15647311     David     Jones          608     Spain  Female
# 2          3    15619304      Hank  Williams          502    France  Female
# 3          4    15701354       Eva    Taylor          699    France  Female
# 4          5    15737888     Grace    Miller          850     Spain  Female
# 5          6    15574012      Jack     Smith          645     Spain    Male
# 6          7    15592531     Carol    Wilson          822    France    Male
# 7          8    15656148     Grace    Wilson          376   Germany  Female
# 8          9    15792365      Hank     Jones          501    France    Male
# 9         10    15592389       Eva    Wilson          684    France    Male
#
#     Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.isnull()   #show how many rows and columns with null values
# Out:
#       RowNumber  CustomerId  Firstname  Lastname  CreditScore  Geography  \
# 0         False       False      False     False        False      False
# 1         False       False      False     False        False      False
# 2         False       False      False     False        False      False
# 3         False       False      False     False        False      False
# 4         False       False      False     False        False      False
# ...         ...         ...        ...       ...          ...        ...
# 9995      False       False      False     False        False      False
# 9996      False       False      False     False        False      False
# 9997      False       False      False     False        False      False
# 9998      False       False      False     False        False      False
# 9999      False       False      False     False        False      False
#
#       Gender    Age  Tenure  Balance  NumOfProducts  HasCrCard  \
# ...

# %%
df.isnull().sum()
# Out:
# RowNumber            0
# CustomerId           0
# Firstname            7
# Lastname             6
# CreditScore          0
# Geography            0
# Gender             108
# Age                600
# Tenure               0
# Balance              0
# NumOfProducts        0
# HasCrCard            0
# IsActiveMember       0
# EstimatedSalary      0
# Exited               0
# dtype: int64

# %% [markdown]
# 3.Handling the Missing Values

# %%
df_cd = df.copy()  #get a copy of the data set

# %%
df_cd.head(5)
# Out:
#    RowNumber  CustomerId Firstname  Lastname  CreditScore Geography  Gender  \
# 0          1    15634602     Grace  Williams          619    France  Female
# 1          2    15647311     David     Jones          608     Spain  Female
# 2          3    15619304      Hank  Williams          502    France  Female
# 3          4    15701354       Eva    Taylor          699    France  Female
# 4          5    15737888     Grace    Miller          850     Spain  Female
#
#     Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0  42.0       2       0.00              1          1               1
# 1  41.0       1   83807.86              1          0               1
# 2  42.0       8  159660.80              3          1               0
# 3   NaN       1       0.00              2          0               0
# 4  43.0       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# ...

# %% [markdown]
# 3.1 Deletion

# %%
df_cp = df.copy()
df_cp = df_cp.dropna(axis=0)   #axis zeor means checking null values across rows and if axis is 1 then i will drop if any clumns consiste of null value
df_cp
# Out:
#       RowNumber  CustomerId Firstname  Lastname  CreditScore Geography  \
# 0             1    15634602     Grace  Williams          619    France
# 1             2    15647311     David     Jones          608     Spain
# 2             3    15619304      Hank  Williams          502    France
# 4             5    15737888     Grace    Miller          850     Spain
# 5             6    15574012      Jack     Smith          645     Spain
# ...         ...         ...       ...       ...          ...       ...
# 9995       9996    15606229     Grace    Garcia          771    France
# 9996       9997    15569892      Jack    Garcia          516    France
# 9997       9998    15584532     Carol   Johnson          709    France
# 9998       9999    15682355      Jack    Garcia          772   Germany
# 9999      10000    15628319       Eva    Garcia          792    France
#
#       Gender   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# ...

# %%
df_cp = df.copy()
df_cp = df_cp.dropna(axis=1)   #axis zeor means checking null values across rows and if axis is 1 then i will drop if any clumns consiste of null value
df_cp
# Out:
#       RowNumber  CustomerId  CreditScore Geography  Tenure    Balance  \
# 0             1    15634602          619    France       2       0.00
# 1             2    15647311          608     Spain       1   83807.86
# 2             3    15619304          502    France       8  159660.80
# 3             4    15701354          699    France       1       0.00
# 4             5    15737888          850     Spain       2  125510.82
# ...         ...         ...          ...       ...     ...        ...
# 9995       9996    15606229          771    France       5       0.00
# 9996       9997    15569892          516    France      10   57369.61
# 9997       9998    15584532          709    France       7       0.00
# 9998       9999    15682355          772   Germany       3   75075.31
# 9999      10000    15628319          792    France       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...
